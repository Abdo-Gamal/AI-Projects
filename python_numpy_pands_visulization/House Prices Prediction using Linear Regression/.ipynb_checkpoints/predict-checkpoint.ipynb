# %% [markdown]
# ![image.png](attachment:6fb60000-617f-4186-9d1b-50450bd1fa27.png)
# ![image.png](attachment:1a57fde7-0b60-4b17-9119-7d1d8c7930a7.png)
# ![image.png](attachment:408530bf-0273-469a-a8e2-72edb25d6b55.png)

# %%
import  numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Data=pd.read_csv("kc_house_data.csv")
Data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    floors  waterfront  view  condition  ...  yr_built  yr_renovated  zipcode  \
# 0     1.0           0     0          3  ...      1955             0    98178
# 1     2.0           0     0          3  ...      1951          1991    98125
# 2     1.0           0     0          3  ...      1933             0    98028
# 3     1.0           0     0          5  ...      1965             0    98136
# 4     1.0           0     0          3  ...      1987             0    98074
#
# ...

# %%
Data.shape
# Out:
# (21613, 21)

# %%
Data.drop("id",axis=1,inplace=True)

# %%
Data.head()

# %%
Data.info()  # some time do not show 
# change object type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  yr_built       21613 non-null  int64
#  12  yr_renovated   21613 non-null  int64
#  13  zipcode        21613 non-null  int64
#  14  lat            21613 non-null  float64
#  15  long           21613 non-null  float64
#  16  sqft_living15  21613 non-null  int64
# ...

# %%
Data.describe() # هشوف الاسعارف فى المتوسط  والمساحه   المتوسطه

# %%
#هحزف الاعمده اللى مش هستخدمها  
Data.columns

# %%
Data.drop(['zipcode', 'lat', 'long'],axis=1,inplace=True)

# %%
Data.head()

# %%
Data.isnull().sum()
# لو فى نول  لو قيم عدديه ممكن ابدها بالمتوسط او القيمه اللى فى النص  
# لو  categoray mod الحل الوحيد ان احط  بدالها 
#mod

# %%
#فى خطوه هنا ان اعمل  groub by
#بس هنسيبها

# %%
# ممكن اعرض السعرع عشان اعرف هقدر اشترى ولا لا 
sns.histplot(Data['price'])

# %%
import plotly.express as px
px.histogram(Data['price'])

# %%
px.box(Data['price'])   # خلى بالك هنا الاسعار البيعده او الكبيره دى من noise  
# دى حقيقيه

# %%
# ايه الفرق بين ال countblot vs bar 
# ان  الاول  بيحتاج اديله الاحداصى الافقى والرئسى فلازم احسبه الاول    اما  ال count  
# مش بتحتاج احسب حاجه هى لوحدها بتحسبب تكرار  عدد الاوض وتعمل بيه الرسمه 
sns.countplot(x=Data['bedrooms'])   # كده انا هعرف  متوسط عدد الاوض فى المنطقه

# %%
sns.countplot(x=Data['floors'])# عدد الطوابق 
# خلى بالك ان عدد الطوابق على المحور الاس 
# ايه النص ده  هتشوف فى وصف الداتا او انك يمعلم

# %%
sns.countplot(Data['bathrooms'])

# %%
sns.countplot(Data['grade'])

# %%
# بعد مرسم كل عمود لوحده عشان افهم الاقيم  هنروح لفهم العلاقات بين كل فيتشر

# %%
Data['age']=Data['yr_built'].apply(lambda x:2022-x)
Data['age']
# Out:
# 0        67
# 1        71
# 2        89
# 3        57
# 4        35
#          ..
# 21608    13
# 21609     8
# 21610    13
# 21611    18
# 21612    14
# Name: age, Length: 21613, dtype: int64

# %%
# لاحظ ان كل اللى بعمله ان بتكلم عن السعر 
sns.scatterplot(x=Data['age'],y=Data['price'])
# مفيش علاقه
# Out:
# <Axes: xlabel='age', ylabel='price'>

# %%
# لاحظ ان كل اللى بعمله ان بتكلم عن السعر 
sns.scatterplot(x=Data['sqft_lot'],y=Data['price']) # دى مساحهsqft_lot 
# مفيش علاقه
# Out:
# <Axes: xlabel='sqft_lot', ylabel='price'>

# %%
# لاحظ ان كل اللى بعمله ان بتكلم عن السعر 
sns.scatterplot(x=Data['sqft_living15'],y=Data['price']) # دى مساحهsqft_living15
# فى  علاقه بس مش قويه
# Out:
# <Axes: xlabel='sqft_living15', ylabel='price'>

# %%
# لاحظ ان كل اللى بعمله ان بتكلم عن السعر 
sns.scatterplot(x=Data['sqft_above'],y=Data['price']) # دى مساحه الادوار المتكرره sqft_above 
#  فى علاقه قويه شويه احسن من الى فاتت
# Out:
# <Axes: xlabel='sqft_above', ylabel='price'>

# %%
# لاحظ ان كل اللى بعمله ان بتكلم عن السعر 
sns.scatterplot(x=Data['sqft_living'],y=Data['price']) # دى مساحه الوحدهsqft_above 
#  فى علاقه قويه احسن من الى كل فاتت
# معنى كده ان اكتر حاجه بتاثر على سعر الشقه هى مساحه الوحده نفسها
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
# فى حاجه هتجبلى كل العلاقات بين كل الفيتشر 

sns.pairplot(Data)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(Data.drop('date',axis=1).corr(),annot=True)
# من خلال الشكل هتعرف  العلاقه بين كل فيتشر والتانى ولو العلاقه قويه ممكن تحزف حد منهم 
# use heatmap can make  feature select
# Out:
# <Axes: >
