# %% [markdown]
# ![image.png](attachment:a7595b65-bf25-417d-809a-b12dc2ea9d1e.png)

# %%
import pandas as pd 
import seaborn as sns

# %%
df=sns.load_dataset('flights')
df1=sns.load_dataset('tips')

print(df.head())
print(df1.head())

df.info()
df1.info()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# ...

# %%
df['passengers'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1[['total_bill','tip','size']].plot.area()   # must have time ser date and numerical
# Out:
# <Axes: >

# %%
df1[['size']].plot.bar()   # must have time ser date and numerical
# Out:
# <Axes: >

# %%
df1[['size','tip']].plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df1[['size','tip']].plot.bar()
# Out:
# <Axes: >

# %%
df1[['size']].plot.line(stacked=True)
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='tip',y='total_bill')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
df1.plot.scatter(x='tip',y='total_bill')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
df1.plot.box()
# Out:
# <Axes: >

# %%
df1[['tip']].plot.kde()  
df1[['size']].plot.kde()
# Out:
# <Axes: ylabel='Density'>
